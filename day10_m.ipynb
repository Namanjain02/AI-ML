# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plit

# %%
img = cv2.imread('test.png')
cv2.imshow(' ',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 24,  21,  20],
#         [ 24,  21,  20],
#         [ 24,  21,  20],
#         ...,
#         [ 24,  21,  20],
#         [ 24,  21,  20],
#         [ 24,  21,  20]],
#
#        [[ 24,  21,  20],
#         [ 24,  21,  20],
#         [ 24,  21,  20],
#         ...,
#         [ 24,  21,  20],
#         [ 24,  21,  20],
#         [ 24,  21,  20]],
#
#        [[ 24,  21,  20],
#         [ 24,  21,  20],
#         [ 24,  21,  20],
#         ...,
#         [ 24,  21,  20],
#         [ 24,  21,  20],
#         [ 24,  21,  20]]], dtype=uint8)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
vid  = cv2.VideoCapture(0)

# %%
vid.isOpened() # camera open karna ma help karta hai
# Out:
# True

# %%
type(vid)
# Out:
# cv2.VideoCapture

# %%
k= vid.read()

# %%
type(k),len(k)
# Out:
# (tuple, 2)

# %%
k[0]
# Out:
# True

# %%
k
# Out:
# (True,
#  array([[[110, 127, 153],
#          [111, 128, 149],
#          [115, 132, 148],
#          ...,
#          [ 60, 103, 143],
#          [ 58, 103, 142],
#          [ 57, 103, 142]],
#
#         [[110, 128, 151],
#          [112, 127, 152],
#          [116, 128, 154],
#          ...,
#          [ 60, 103, 142],
#          [ 60, 104, 141],
#          [ 60, 104, 140]],
#
#         [[106, 125, 151],
#          [109, 125, 151],
#          [114, 126, 152],
#          ...,
#          [ 63, 103, 142],
#          [ 64, 104, 139],
#          [ 64, 104, 138]],
#
#         ...,
#
#         [[ 19,  21,  21],
#          [ 20,  22,  22],
#          [ 19,  21,  21],
#          ...,
#          [ 37,  46,  56],
#          [ 39,  46,  55],
#          [ 40,  46,  55]],
#
#         [[ 22,  25,  24],
#          [ 23,  25,  24],
#          [ 24,  26,  26],
#          ...,
#          [ 34,  47,  61],
#          [ 33,  46,  60],
#          [ 33,  46,  60]],
#
#         [[ 18,  28,  27],
#          [ 20,  28,  26],
#          [ 19,  26,  26],
#          ...,
#          [ 36,  45,  66],
#          [ 37,  45,  60],
#          [ 37,  45,  60]]], dtype=uint8))

# %%
flag,img  = vid.read()

# %%
if flag:
    plt.imshow(img[ :,:,::-1 ])

# %% [markdown]
# img.shape

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
ord('a')
# Out:
# 97

# %%
vid.release()  # flash off karnaa me help karta hai

# %%
vid = cv2.VideoCapture(0)
while True:
    flag,img = vid.read()
    if flag:
        # processing code
        img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #  image ka color change karna ma help karta ha
        print(type(img_gray))
        break
        ##
        cv2.imshow('preview',img)
        key = cv2.waitKey(1)
        if key == ord('q'):  # off karna ka liya key di gyi ha q name ki
            break
    else:
        break
vid.release()
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>

# %%
vid = cv2.VideoCapture(0)
while True:
    flag,img = vid.read()
    if flag:
        # processing code
        img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #  image ka color change karna ma help karta ha
        th, img_bw = cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY)
        cv2.imshow('preview',img_bw)
        key = cv2.waitKey(1)
        if key == ord('q'):  # off karna ka liya key di gyi ha q name ki
            break
    else:
        print('No Frames')
        break
vid.release()
cv2.destroyAllWindows()

# %%
vid = cv2.VideoCapture(0)
while True:
    flag,img = vid.read()
    if flag:
        # processing code
        img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #  image ka color change karna ma help karta ha
        th, img_bw = cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY)
        x,y,w,h =(200,200,100,100) 
        img_crooped =  img[y:y+h,x:x+w, :]
        cv2.rectangle(img,pt1=(x,y), pt2 = (x+w,y+h),color=(0,0,255),thickness=8)
        cv2.imshow('preview',img_crooped)
        key = cv2.waitKey(1)
        if key == ord('q'):  # off karna ka liya key di gyi ha q name ki
            break
    else:
        print('No Frames')
        break
vid.release()
cv2.waitKey(1)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plit
fd = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')
vid = cv2.VideoCapture(0)
while True:
    flag,img = vid.read()
    if flag:
        # processing code
        img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #  image ka color change karna ma help karta ha
        faces =fd.detechMultiscale(img_gray,1.1,5)
        

        # th, img_bw = cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY)
        for x,y,w,h in faces:
            # x,y,w,h =(200,200,100,100) 
            # # img_crooped =  img[y:y+h,x:x+w, :]
            cv2.rectangle
            (img,pt1=(x,y), pt2 = (x+w,y+h),color=(0,0,255),
            thickness=8
            )
        cv2.imshow('preview',img_crooped)
        key = cv2.waitKey(1)
        if key == ord('q'):  # off karna ka liya key di gyi ha q name ki
            break
    else:
        print('No Frames')
        break
vid.release()
cv2.waitKey(1)
cv2.destroyAllWindows()
# Out:
#   Cell In[1], line 18
#     (img,pt1=(x,y), pt2 = (x+w,y+h),color=(0,0,255),
#          ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
m=(3,4)

# %%
m
# Out:
# (3, 4)

# %%
m,n = (3,4)

# %%
m
# Out:
# 3

# %%
n
# Out:
# 4
